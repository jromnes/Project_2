# %% [markdown]
# # TSM Trading Algorithm

# %% [markdown]
# ### Imports

# %%
# Imports
import os
import requests
import pandas as pd
import numpy as np
import seaborn as sns
from pathlib import Path
import hvplot.pandas
import holoviews as hv
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.preprocessing import StandardScaler
from pandas.tseries.offsets import DateOffset
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from imblearn.over_sampling import RandomOverSampler
import yfinance as yf
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="d4600793-11be-4de7-94cc-573511cf5e2d" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ### Data Collection:
# All data was collected using Yahoo Finance

# %%
# Data collected through yahoo finance
symbol = 'TSM' 
stock = yf.Ticker(symbol)
start_date = '2000-01-01'
end_date = '2024-01-01'

# %%
#Dataframe of historical TSM data created
stock_df = stock.history(interval='1d',
                      start=start_date,
                      end=end_date,
                      actions=False,
                      auto_adjust=True,
)
stock_df.head()
# Out:
#                                Open      High       Low     Close   Volume
# Date
# 2000-01-03 00:00:00-05:00  9.102112  9.150271  8.873356  9.126191  2062807
# 2000-01-04 00:00:00-05:00  9.126187  9.487382  9.102108  9.186386  2557142
# 2000-01-05 00:00:00-05:00  9.270671  9.330870  9.186391  9.246592  2295467
# 2000-01-06 00:00:00-05:00  9.029873  9.041912  8.668677  8.861315  1539456
# 2000-01-07 00:00:00-05:00  9.174351  9.246591  9.053952  9.198431  1511230

# %% [markdown]
# ### Data Preprocessing:
# Clean and preprocess the collected data. Addition of any necessary columns for data analysis.

# %%
# Adding columns for Daily Returns of TSM
stock_df['TSM_Returns'] = stock_df['Close'].pct_change()
stock_df.dropna(inplace=True)
stock_df.drop(columns='Volume', inplace=True)
stock_df.head()
# Out:
#                                Open      High       Low     Close  TSM_Returns
# Date
# 2000-01-04 00:00:00-05:00  9.126187  9.487382  9.102108  9.186386     0.006596
# 2000-01-05 00:00:00-05:00  9.270671  9.330870  9.186391  9.246592     0.006554
# 2000-01-06 00:00:00-05:00  9.029873  9.041912  8.668677  8.861315    -0.041667
# 2000-01-07 00:00:00-05:00  9.174351  9.246591  9.053952  9.198431     0.038044
# 2000-01-10 00:00:00-05:00  9.499424  9.571663  9.366986  9.571663     0.040576

# %% [markdown]
# #### Visualization of TSM closing price

# %%
# Plotting Closing Price of TSM
close = stock_df[['Close']].hvplot(
    line_color='lightgray',
    ylabel='Price in $',
    width=1000,
    height=400)
close
# Out:
# :Curve   [Date]   (Close)

# %% [markdown]
# #### Visualization of TSM Cumulative Returns

# %%
# Plotting cumulative returns of TSM
tsm_cumulative_returns_plot = (1 + stock_df[['TSM_Returns']]).cumprod().plot()
tsm_cumulative_returns_plot
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Indicators and signals generated

# %% [markdown]
# #### RSI

# %%
# Defining a function to calculate RSI Data
def calculate_rsi(data, window):
    delta = data.diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

# Define the window size for RSI calculation
window = 14

# Calculate RSI for the 'TSM' column
stock_df['RSI'] = calculate_rsi(stock_df['Close'], window)
stock_df.dropna(inplace=True)
stock_df.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2000-01-24 00:00:00-05:00  10.859927  11.799033  10.835847  11.498037
# 2000-01-25 00:00:00-05:00  11.498039  12.665904  11.486000  12.617744
# 2000-01-26 00:00:00-05:00  12.954855  13.869882  12.087988  12.184306
# 2000-01-27 00:00:00-05:00  11.630474  11.642513  11.124801  11.341518
# 2000-01-28 00:00:00-05:00  11.076644  11.100723  10.414453  10.462612
#
#                            TSM_Returns        RSI
# Date
# 2000-01-24 00:00:00-05:00     0.092678  76.666627
# 2000-01-25 00:00:00-05:00     0.097382  81.456920
# 2000-01-26 00:00:00-05:00    -0.034351  75.206514
# 2000-01-27 00:00:00-05:00    -0.069170  69.731752
# 2000-01-28 00:00:00-05:00    -0.077495  59.259239

# %%
# Visualization of RSI
rsi_plot = stock_df['RSI'].hvplot(figsize=(12, 6), title='Relative Strength Index (RSI)', xlabel='Date', ylabel='RSI', color='blue')
rsi_plot
# Out:
# WARNING:param.main: hvPlot does not have the concept of a figure, and the figsize keyword will be ignored. The size of each subplot in a layout is set individually using the width and height options.
# :Curve   [Date]   (RSI)

# %% [markdown]
# #### Stochastic Oscillator (14, 6, 6)

# %%
# Function to calculate stochastic oscillator (14, 6, 6)
def calculate_stochastic_oscillator(high, low, close, k_window=14, d_window=6):
    lowest_low = low.rolling(window=k_window).min()
    highest_high = high.rolling(window=k_window).max()
    k_percent = ((close - lowest_low) / (highest_high - lowest_low)) * 100
    d_percent = k_percent.rolling(window=d_window).mean()
    return k_percent, d_percent

# Assuming you have 'High', 'Low', and 'Close' columns in your DataFrame
# Calculate stochastic oscillator (14, 6, 6)
stock_df['%K'], stock_df['%D'] = calculate_stochastic_oscillator(stock_df['High'], stock_df['Low'], stock_df['Close'])
stock_df.dropna(inplace=True)
# Display the DataFrame with stochastic oscillator values
stock_df.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2000-02-17 00:00:00-05:00  11.955549  12.075946  11.895350  12.063907
# 2000-02-18 00:00:00-05:00  11.558238  11.606398  11.389681  11.510078
# 2000-02-22 00:00:00-05:00  11.028481  11.245199  10.799724  10.884004
# 2000-02-23 00:00:00-05:00  10.787688  10.871968  10.595051  10.595051
# 2000-02-24 00:00:00-05:00  10.691372  10.835850  10.486695  10.787690
#
#                            TSM_Returns        RSI         %K         %D
# Date
# 2000-02-17 00:00:00-05:00     0.009063  61.728405  59.872517  56.878831
# 2000-02-18 00:00:00-05:00    -0.045908  60.975632  40.893533  52.796987
# 2000-02-22 00:00:00-05:00    -0.054394  47.528502   3.030323  44.919397
# 2000-02-23 00:00:00-05:00    -0.026548  45.703829   0.000000  36.142290
# 2000-02-24 00:00:00-05:00     0.018182  24.234647   9.727619  28.421741

# %%
# Visualization of Stochastic Oscillator
stoch_plot = stock_df[['%K', '%D']].hvplot(title='Stochastic Oscillator', xlabel='Date', ylabel='Percentage', 
                               line_color=['blue', 'orange'])
stoch_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (value)

# %% [markdown]
# #### Strategy signals created

# %%
# Initializing capital, percentage of capital per trade, and shares
capital = 100000  # Initial capital
percentage_of_capital = 0.05  # 5%
initial_shares = int(capital * 0.60)  # 60% of the initial account value
shares = initial_shares # Number of shares held


# Initializing list to store entry/exit signals, strategy returns, and account values
entry_exit_signals = []
strategy_returns = []
account_values = []

# Looping through the stock_df to execute trades and record signals
for index, row in stock_df.iterrows():
    if (row['RSI'] < 30) & (row['%K'] < 20):  # Buy signal conditions
        shares_to_buy = int((capital * percentage_of_capital) / row['Close'])
        shares += shares_to_buy
        capital -= shares_to_buy * row['Close']
        entry_exit_signals.append('Buy')
        strategy_returns.append((shares_to_buy * row['Close']) / capital)
    elif ((row['RSI'] > 70) & (row['%K'] > 80)) and (shares > 0):  # Sell signal conditions
        capital += shares * row['Close']
        shares = initial_shares
        entry_exit_signals.append('Sell')
        strategy_returns.append((capital - shares * row['Close']) / capital)
    else:
        entry_exit_signals.append('Hold')
        strategy_returns.append(0.0)
    
    # Calculate account value after each trade
    account_value = capital + shares * row['Close']
    account_values.append(account_value)

# Adding entry/exit signals, strategy returns, and account values to stock_df
stock_df['Entry/Exit'] = entry_exit_signals
stock_df['Strategy_Return'] = strategy_returns
stock_df['Account_Value'] = account_values

# Calculate final profit/loss
final_balance = capital + shares * stock_df.iloc[-1]['Close']
initial_balance = 100000
profit_loss = final_balance - initial_balance

# Print final profit/loss
print("Final balance:", final_balance)
print("Profit/loss:", profit_loss)
# Out:
# Final balance: 1210829472.6812332
# Profit/loss: 1210729472.6812332

# %%
# Previewing new columns added to stock_df
stock_df.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2000-02-17 00:00:00-05:00  11.955549  12.075946  11.895350  12.063907
# 2000-02-18 00:00:00-05:00  11.558238  11.606398  11.389681  11.510078
# 2000-02-22 00:00:00-05:00  11.028481  11.245199  10.799724  10.884004
# 2000-02-23 00:00:00-05:00  10.787688  10.871968  10.595051  10.595051
# 2000-02-24 00:00:00-05:00  10.691372  10.835850  10.486695  10.787690
#
#                            TSM_Returns        RSI         %K         %D  \
# Date
# 2000-02-17 00:00:00-05:00     0.009063  61.728405  59.872517  56.878831
# 2000-02-18 00:00:00-05:00    -0.045908  60.975632  40.893533  52.796987
# 2000-02-22 00:00:00-05:00    -0.054394  47.528502   3.030323  44.919397
# 2000-02-23 00:00:00-05:00    -0.026548  45.703829   0.000000  36.142290
# 2000-02-24 00:00:00-05:00     0.018182  24.234647   9.727619  28.421741
#
#                           Entry/Exit  Strategy_Return  Account_Value
# Date
# ...

# %% [markdown]
# #### Visualization of Account Value

# %%
# Plotting Account Value
account_value = stock_df['Account_Value'].hvplot(title='Account Value', xlabel='Date', ylabel='Account Balance $', line_color=['blue', 'orange'], figsize=(10, 6)).opts(yformatter='%.0f')

account_value
# Out:
# WARNING:param.main: hvPlot does not have the concept of a figure, and the figsize keyword will be ignored. The size of each subplot in a layout is set individually using the width and height options.
# :Curve   [Date]   (Account_Value)

# %% [markdown]
# #### Visualization of Entry & Exit Points

# %%
# Visualize entry positions relative to close price
entry = stock_df[stock_df['Entry/Exit'] == 'Buy']['Close'].hvplot.scatter(
    color='green',
    marker='^',
    legend=True,
    ylabel='Price in $',
    width=1000,
    height=400)

# Visualize exit positions relative to close price
exit = stock_df[stock_df['Entry/Exit'] == 'Sell']['Close'].hvplot.scatter(
    color='red',
    marker='v',
    legend=True,
    ylabel='Price in $',
    width=1000,
    height=400)

# Plot the entry and exit points with the closing price of TSM
close * entry * exit
# Out:
# :Overlay
#    .Curve.I          :Curve   [Date]   (Close)
#    .Scatter.Close.I  :Scatter   [Date]   (Close)
#    .Scatter.Close.II :Scatter   [Date]   (Close)

# %% [markdown]
# ### Split the data into training and testing datasets.

# %%
# Define features and target variable
features = ['RSI', '%K', '%D']
target = 'Entry/Exit'

# %%
# Assign %K, %D & RSI columns to a features DataFrame called X
X = stock_df[features].shift().dropna()

# Review the DataFrame
X.head()
# Out:
#                                  RSI         %K         %D
# Date
# 2000-02-18 00:00:00-05:00  61.728405  59.872517  56.878831
# 2000-02-22 00:00:00-05:00  60.975632  40.893533  52.796987
# 2000-02-23 00:00:00-05:00  47.528502   3.030323  44.919397
# 2000-02-24 00:00:00-05:00  45.703829   0.000000  36.142290
# 2000-02-25 00:00:00-05:00  24.234647   9.727619  28.421741

# %%
# Create the target set selecting the entry/exit column and assiging it to y
y = stock_df[target]

# Review the value counts
y.value_counts()
# Out:
# Entry/Exit
# Hold    4951
# Sell     642
# Buy      412
# Name: count, dtype: int64

# %%
# Select the start of the training period
training_begin = X.index.min()

# Display the training begin date
print(training_begin)
# Out:
# 2000-02-18 00:00:00-05:00

# %%
# Select the ending period for the training data with an offset of [x] months
training_end = X.index.min() + DateOffset(months=144)

# Display the training end date
print(training_end)
# Out:
# 2012-02-18 00:00:00-05:00

# %%
# Generate the X_train and y_train DataFrames
X_train = X.loc[training_begin:training_end]
y_train = y.loc[training_begin:training_end]

# Review the X_train DataFrame
X_train.head()
# Out:
#                                  RSI         %K         %D
# Date
# 2000-02-18 00:00:00-05:00  61.728405  59.872517  56.878831
# 2000-02-22 00:00:00-05:00  60.975632  40.893533  52.796987
# 2000-02-23 00:00:00-05:00  47.528502   3.030323  44.919397
# 2000-02-24 00:00:00-05:00  45.703829   0.000000  36.142290
# 2000-02-25 00:00:00-05:00  24.234647   9.727619  28.421741

# %%
# Generate the X_test and y_test DataFrames
X_test = X.loc[training_end+DateOffset(hours=1):]
y_test = y.loc[training_end+DateOffset(hours=1):]

# Review the X_test DataFrame
X_test.head()
# Out:
#                                  RSI         %K         %D
# Date
# 2012-02-21 00:00:00-05:00  64.545517  84.693871  62.703313
# 2012-02-22 00:00:00-05:00  56.410237  60.203960  71.435228
# 2012-02-23 00:00:00-05:00  56.223200  70.408379  74.836561
# 2012-02-24 00:00:00-05:00  54.811720  35.714604  70.632698
# 2012-02-27 00:00:00-05:00  56.451627  59.183657  67.312561

# %% [markdown]
# ### Model Training

# %% [markdown]
# #### StandardScaler
# The Standard Scaler code is here to show that we did utilize it, but the Random Over Sampler performed better for our model's purpose

# %%
# Scale the features DataFrames

# Create a StandardScaler instance
#scaler = StandardScaler()

# Apply the scaler model to fit the X-train data
#X_scaler = scaler.fit(X_train)

# Transform the X_train and X_test DataFrames using the X_scaler
#X_train_scaled = X_scaler.transform(X_train)
#X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# #### RandomOverSampler

# %%
# Instantiate the RandomOverSampler instance
random_oversampler = RandomOverSampler(random_state=1)

# Fit the data to the model
X_resampled, y_resampled = random_oversampler.fit_resample(X_train, y_train)

# %% [markdown]
# For each model please restart kernel and run all cells up to this point. To run the different models you need to skip over and continue running the model you would like. All code is featured to show the work but each model has to run separately. This way all data is scaled pre model training. Only run one model at a time then skip to the Backtesting Section

# %% [markdown]
# #### Gradient Boosting Machines (GBM) Classifier

# %%
# Initialize the GradientBoostingClassifier
gbm = GradientBoostingClassifier()

# Train the model
gbm.fit(X_resampled, y_resampled)

# Predict on the test set
gbm_pred = gbm.predict(X_test)

accuracy = accuracy_score(y_test, gbm_pred)
print("Accuracy:", accuracy)
# Generate classification report
print("Classification Report:")
print(classification_report(y_test, gbm_pred))
# Out:
# Accuracy: 0.790284757118928
# Classification Report:
#               precision    recall  f1-score   support
#
#          Buy       0.49      0.88      0.63       211
#         Hold       0.96      0.77      0.85      2390
#         Sell       0.48      0.88      0.62       384
#
#     accuracy                           0.79      2985
#    macro avg       0.65      0.84      0.70      2985
# weighted avg       0.87      0.79      0.81      2985

# %% [markdown]
# #### SVC Classifier

# %%
# From SVM, instantiate SVC classifier model instance
#svm_model = svm.SVC()
 
# Fit the model to the data using the training data
#svm_model = svm_model.fit(X_resampled, y_resampled)
 
# Use the testing data to make the model predictions
#svm_pred = svm_model.predict(X_test)

#accuracy = accuracy_score(y_test, svm_pred)
#print("Accuracy:", accuracy)
# Generate classification report
#print("Classification Report:")
#print(classification_report(y_test, svm_pred))

# %% [markdown]
# #### SGD Classifier

# %%
# Create an SGDClassifier with logistic loss function
#sgd_model = SGDClassifier()

# Fit the model on training data
#sgd_model.fit(X_resampled, y_resampled)

# Predict on the testing data
#sgd_pred = sgd_model.predict(X_test)

#accuracy = accuracy_score(y_test, sgd_pred)
#print("Accuracy:", accuracy)
# Generate classification report
#print("Classification Report:")
#print(classification_report(y_test, sgd_pred))

# %% [markdown]
# #### LogisticRegression Model

# %%
# Initiate the model instance
#logistic_regression_model = LogisticRegression()

# Fit the model using the training data
#logistic_regression_model.fit(X_resampled, y_resampled)

# Use the testing dataset to generate the predictions for the new model
#lr_pred = logistic_regression_model.predict(X_test)

#accuracy = accuracy_score(y_test, lr_pred)
#print("Accuracy:", accuracy)
# Generate classification report
#print("Classification Report:")
#print(classification_report(y_test, lr_pred))

# %% [markdown]
# ### Actual Returns vs Strategy Returns

# %%
# Initialize initial capital and shares
initial_capital = 100000
percentage_of_capital = 0.05
initial_shares = int(initial_capital * 0.60)
shares = initial_shares
capital = initial_capital

# Initialize list to store account values
predicted_account_values = []

# Loop through each row of the DataFrame
for index, row in predictions_df.iterrows():
    # Calculate the account value based on the predicted returns
    predicted_account_value = capital + (shares * row['Model_Returns'])
    
    # Store the account value in the list
    predicted_account_values.append(predicted_account_value)
    
    # Update capital and shares based on the predicted returns
    capital += (shares * row['Model_Returns'])
    shares = initial_shares

# Add the predicted account values to the DataFrame
predictions_df['Predicted_Account_Value'] = predicted_account_values

# %%
predictions_df.head()
# Out:
#                           Predicted  TSM_Returns  Model_Returns  \
# Date
# 2012-02-21 00:00:00-05:00      Sell    -0.016416       0.016416
# 2012-02-22 00:00:00-05:00      Hold     0.006954       0.000000
# 2012-02-23 00:00:00-05:00      Hold    -0.023481      -0.000000
# 2012-02-24 00:00:00-05:00      Hold     0.016266       0.000000
# 2012-02-27 00:00:00-05:00      Hold     0.001392       0.000000
#
#                            Predicted_Account_Value
# Date
# 2012-02-21 00:00:00-05:00            100984.960123
# 2012-02-22 00:00:00-05:00            100984.960123
# 2012-02-23 00:00:00-05:00            100984.960123
# 2012-02-24 00:00:00-05:00            100984.960123
# 2012-02-27 00:00:00-05:00            100984.960123

# %%
# Create the line plot using hvplot
predicted_account_value = predictions_df['Predicted_Account_Value'].hvplot.line(title='Cumulative Returns', xlabel='Date', ylabel='Predicted Account Value').opts(yformatter='%.0f')

# Display the plot
predicted_account_value * account_value
# Out:
# :Overlay
#    .Curve.Predicted_Account_Value :Curve   [Date]   (Predicted_Account_Value)
#    .Curve.Account_Value           :Curve   [Date]   (Account_Value)
